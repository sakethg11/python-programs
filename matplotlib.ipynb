# %% [markdown]
# <a href="https://colab.research.google.com/github/sakethg11/python-programs/blob/module-4/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([98,87,88,75,83,50])
mylabels= ['chemistry','maths','c language','physics','evpr','beee']
plt.pie(y,labels=mylabels)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([98,87,88,75,83,50])
mylabels=['chemistry','maths','c language','physics','evpr','beee']
myexplode=[0.2,0,0,0,0,0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as py
x=np.array(['c language','maths','chemistry','evpr'])
y=np.array([93,78,87,95])
plt.barh(x,y, color='yellow')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['c language','maths','chemistry','evpr'])
y = np.array([93,78,87,95])

plt.barh(x, y, height = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([98,87,88,75,83,50])
mylabels= ['chemistry','maths','c language','physics','evpr','beee']
plt.pie(y,labels=mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 2, 4, 6])
y = np.array([3, 7, 2, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()
